# %%
from sklearn import datasets

# %%
diabetes = datasets.load_diabetes()

# %%
diabetes
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
print(diabetes.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
print(diabetes.feature_names)
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
X = diabetes.data
Y = diabetes.target

# %%
X.shape, Y.shape
# Out:
# ((442, 10), (442,))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((353, 10), (353,), (89, 10), (89,))

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
  model= linear_model.LinearRegression()

# %% [markdown]
# model.fit(X_train, Y_train)

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)

# %%
print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
print('Mean squared error (MSE): %.2f'% mean_squared_error(Y_test, Y_pred))
print('Coefficient of determination (R^2): %.2f'% r2_score(Y_test, Y_pred))
# Out:
# Coefficients: [ -36.39157019 -196.56806133  595.90318232  267.06930705 -673.79403586
#   413.69482183   68.00664795   80.95601386  766.96192494   34.30309793]
# Intercept: 150.7455399885983
# Mean squared error (MSE): 3254.23
# Coefficient of determination (R^2): 0.44

# %%
import seaborn as sns

# %%
Y_test
# Out:
# array([275., 217., 237.,  48.,  94.,  88., 272., 233., 263., 121., 158.,
#        242.,  95., 144.,  99., 101.,  93.,  69., 152., 259., 150., 191.,
#        192., 137.,  42., 310., 107.,  96., 257.,  85., 262., 341., 281.,
#        143., 178., 248.,  91., 288., 317., 229., 245., 186., 146., 258.,
#         85.,  75., 110., 306., 200., 168., 168., 178., 198.,  49.,  68.,
#         59.,  72., 156., 245., 116., 129., 200., 158., 189., 108., 296.,
#        172., 140.,  88., 174.,  87., 129., 177., 173., 292., 118.,  91.,
#        142., 246., 183.,  43., 270., 202., 243., 253.,  85.,  83., 150.,
#        109.])

# %%
Y_pred
# Out:
# array([211.09944872, 175.27759836, 156.72487523,  65.73335466,
#        101.5749337 , 106.83905762, 237.31250664, 264.3447455 ,
#        183.60273911, 212.69674793,  71.21206836, 273.26668114,
#        157.54909845, 122.25433021,  56.61632721, 187.09466448,
#        139.02355515,  99.70757038, 115.5829956 , 155.74246826,
#        203.25374295, 188.60054798, 218.90122509,  93.69070256,
#        126.80639617, 253.92328523, 112.5731339 ,  64.38066111,
#        221.70958185, 150.46225919, 155.31309016, 255.78117509,
#        218.45666396, 172.21816129, 159.29704174, 203.72588455,
#        166.03489134, 207.19516669, 221.17953149, 188.11787929,
#        163.87399852, 202.72384549, 126.98277351, 229.72098248,
#         57.09623044,  70.49236894, 164.04399931, 247.82296096,
#        182.90998069, 137.22168606, 139.3977645 , 112.75876578,
#        204.4085477 , 127.93985819, 200.27514101, 124.73453788,
#         94.1695701 , 155.46194254, 253.80437917, 141.85966744,
# ...

# %%
sns.scatterplot(x=Y_test,y=Y_pred)
# Out:
# <Axes: >

# %%
 # Seaborn.scatterplot does not accept two positional arguments directly as you've written it. It requires that the x and y data are passed as keyword arguments, not as positional arguments.

# %%
sns.scatterplot(x=Y_test,y=Y_pred, marker="+")
# Just to modify the markers from bullets to plus
# Out:
# <Axes: >

# %%
sns.scatterplot(x=Y_test,y=Y_pred, alpha=0.5)
#print('Alpha is used to make the data points translucent')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.scatter(Y_test, Y_pred)
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], color='red') # Line of best fit
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.show()

# %%
sns.residplot(x=Y_pred, y=(Y_test - Y_pred))
# Out:
# <Axes: >

# %%
sns.histplot(Y_pred, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
stats.probplot(Y_test - Y_pred, dist="norm", plot=plt)
plt.show()

# %%
from statsmodels.stats.outliers_influence import OLSInfluence
import statsmodels.api as sm
model_stats = sm.OLS(Y_train, X_train).fit()
influence = OLSInfluence(model_stats)
sns.scatterplot(x=range(len(influence.cooks_distance[0])), y=influence.cooks_distance[0])
# Out:
# <Axes: >

# %% [markdown]
# Below Explanation in the Readme section:

# %%
import pandas as pd
data = pd.read_csv('score.csv')

# %%
data
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# ..    ...     ...
# 91    5.8      60
# 92    4.4      44
# 93    6.1      63
# 94    3.7      37
# 95    8.0      84
#
# [96 rows x 2 columns]

# %%
plt.scatter(data.Hours, data.Scores)

# %%
def gradient_descent(m_now, b_now, points, L):
    m_gradient = 0
    b_gradient= 0
    n=len(points)
    for i in range(n):
        x = points.iloc[i].Hours
        y=points.iloc[i].Scores
        m_gradient += -(2/n)*x*(y-(m_now*x + b_now))
        b_gradient += -(2/n)*(y-(m_now*x + b_now))
    m = m_now - m_gradient*L
    b = b_now - b_gradient*L
    return m,b

m = 0
b = 0
L=0.001
epochs = 400

for i in range(epochs):
    m,b = gradient_descent(m,b,data,L)

print(m,b)
MSE=0
n=len(data)
for i in range(n):
    x = data.iloc[i].Hours
    y=data.iloc[i].Scores
    MSE +=  y - (m*x + b)
print(MSE) # Mean Square Error To determine the efficiency of the predictions.
plt.scatter(data.Hours, data.Scores, color='black')
plt.plot(list(range(1,10)),[m*x + b for x in range(1,10)],color='red' )
# Out:
# 9.943451014687065 1.5934710688181255
# 4.623599266210968
